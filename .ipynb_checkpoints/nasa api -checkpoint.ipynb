# %%
import requests
import pandas as pd
import numpy as np
import xarray as xr
import netCDF4 as nc
from datetime import datetime, timedelta
import os
import urllib.request
from urllib.parse import urljoin
import json
import time

# %%
class GLDASFetcher:
    def __init__(self, username, password):
        """
        Initialize GLDAS data fetcher with NASA Earthdata credentials
        
        Args:
            username (str): NASA Earthdata username (REQUIRED)
            password (str): NASA Earthdata password (REQUIRED)
        """
            
        self.username = username
        self.password = password
        
        # NASA GES DISC endpoints
        self.ges_disc_base = "https://hydro1.gesdisc.eosdis.nasa.gov"
        self.opendap_base = "https://hydro1.gesdisc.eosdis.nasa.gov/opendap"
        
        # GLDAS dataset paths
        self.datasets = {
            "GLDAS_NOAH025_D": "daily_aggregated",               # Daily aggregated
        }
        
        # GLDAS variable names (actual NetCDF variable names)
        self.variables = {
            'temp': 'Tair_f_inst',           # Temperature at 2m (K)
            'humidity': 'Qair_f_inst',        # Specific humidity at 2m (kg/kg)
            'pressure': 'Psurf_f_inst',       # Surface pressure (Pa)
            'wind_u': 'W2SM',          # Wind speed (m/s)
            'precipitation': 'Rainf_f_tavg',  # Rainfall rate (kg/m^2/s)
            'solar_rad': 'SWdown_f_tavg',     # Solar radiation (W/m^2)
                    
        }

    
    def get_data(self, lat, lon, start_date, end_date, variables=None, dataset="GLDAS_NOAH025_D"):
        """
        Fetch GLDAS daily data from NASA
        
        Args:
            lat (float): Latitude (-60 to 90 for GLDAS coverage)
            lon (float): Longitude (-180 to 180)
            start_date (str): Start date 'YYYY-MM-DD'
            end_date (str): End date 'YYYY-MM-DD'
            variables (list): Variables to fetch
            dataset (str): GLDAS dataset to use (default: daily)
            
        Returns:
            pandas.DataFrame: Real GLDAS daily data
        """
        if variables is None:
            variables = ['temp', 'humidity', 'pressure', 'precipitation','Wind Speed']
        
        print(f"🌍 Fetching GLDAS DAILY data from NASA")
        print(f"📍 Location: ({lat}, {lon})")
        print(f"📅 Dates: {start_date} to {end_date}")
        print(f"📊 Variables: {variables}")
        print(f"🗂️ Dataset: Daily aggregated")
        
        # Convert dates
        start_dt = datetime.strptime(start_date, '%Y-%m-%d')
        end_dt = datetime.strptime(end_date, '%Y-%m-%d')
        
        all_data = []
        current_date = start_dt
        
        while current_date <= end_dt:
            
            # Get daily aggregated data for this date
            daily_data = self._fetch_daily_aggregated_data(lat, lon, current_date, variables)
            if daily_data is not None:
                all_data.append(daily_data)
                    
            current_date += timedelta(days=1)
            time.sleep(0.1) 

        if all_data:
            # Combine all data
            combined_df = pd.DataFrame(all_data)
            combined_df.set_index('date', inplace=True)
            combined_df = combined_df.sort_index()
            
            print(f"✅ Successfully fetched {len(combined_df)} daily records")
            return combined_df
        else:
            print("❌ No data could be fetched")
            return pd.DataFrame()
    
    def _fetch_daily_aggregated_data(self, lat, lon, date, variables):
        """Fetch daily aggregated data from NASA GLDAS/POWER"""
        
        try:
            print(f"🔄 Fetching daily data for: {date.strftime('%Y-%m-%d')}")
            
            # Use NASA POWER API for daily meteorological data
            real_data = self._get_nasa_power_daily_data(lat, lon, date, variables)
            
            return real_data
            
        except Exception as e:
            print(f"Error fetching daily data: {e}")
            return None
    
    def _get_nasa_power_daily_data(self, lat, lon, date, variables):
        """Get daily data from NASA POWER API"""
        
        try:
            # NASA POWER API for daily meteorological data
            base_url = "https://power.larc.nasa.gov/api/temporal/daily/point"
            
            # Map our variables to POWER daily parameters
            power_params = []
            if 'temp' in variables:
                power_params.extend(['T2M_MAX', 'T2M_MIN'])  # min,max temp
            if 'humidity' in variables:
                power_params.extend(['QV2M'])  # Specific humidity
            if 'pressure' in variables:
                power_params.append('PS')   # Surface pressure
            if 'precipitation' in variables:
                power_params.append('PRECTOTCORR')  # Daily precipitation (corrected)
            if 'solar_rad' in variables:
                power_params.append('ALLSKY_SFC_SW_DWN')  # Solar radiation
            if 'wind_speed' in variables:
                power_params.append('WS2M')  # Wind speed

            if not power_params:
                return None
            
            params = {
                'parameters': ','.join(power_params),
                'community': 'RE',
                'longitude': lon,
                'latitude': lat,
                'start': date.strftime('%Y%m%d'),
                'end': date.strftime('%Y%m%d'),
                'format': 'JSON'
            }
            
            # Make request to NASA POWER
            response = requests.get(base_url, params=params, timeout=30)
            
            if response.status_code == 200:
                data = response.json()
                
                # Extract the daily data
                record = {
                    'date': date.date(),
                    'latitude': lat,
                    'longitude': lon
                }
                
                date_key = f"{date.year:04d}{date.month:02d}{date.day:02d}"
                
                # Map POWER data to our variable names (daily aggregations)
                if 'temp' in variables:
                    if 'T2M_MAX' in data['properties']['parameter'] and date_key in data['properties']['parameter']['T2M_MAX']:
                        record['temp_max'] = data['properties']['parameter']['T2M_MAX'][date_key]
                    if 'T2M_MIN' in data['properties']['parameter'] and date_key in data['properties']['parameter']['T2M_MIN']:
                        record['temp_min'] = data['properties']['parameter']['T2M_MIN'][date_key]        
                    
                if 'humidity' in variables:
                    if 'QV2M' in data['properties']['parameter'] and date_key in data['properties']['parameter']['QV2M']:
                        record['humidity_specific'] = data['properties']['parameter']['QV2M'][date_key]
                    
                if 'pressure' in variables:
                    if 'PS' in data['properties']['parameter'] and date_key in data['properties']['parameter']['PS']:
                        record['pressure'] = data['properties']['parameter']['PS'][date_key]
                
                if 'precipitation' in variables:
                    if 'PRECTOTCORR' in data['properties']['parameter'] and date_key in data['properties']['parameter']['PRECTOTCORR']:
                        record['precipitation_total'] = data['properties']['parameter']['PRECTOTCORR'][date_key]
                
                if 'solar_rad' in variables:
                    if 'ALLSKY_SFC_SW_DWN' in data['properties']['parameter'] and date_key in data['properties']['parameter']['ALLSKY_SFC_SW_DWN']:
                        record['solar_radiation'] = data['properties']['parameter']['ALLSKY_SFC_SW_DWN'][date_key]
                
                
                if 'wind_speed' in variables:
                    if 'WS2M' in data['properties']['parameter'] and date_key in data['properties']['parameter']['WS2M']:
                        record['wind_speed'] = data['properties']['parameter']['WS2M'][date_key]

                return record
            else:
                print(f"NASA POWER API error: {response.status_code}")
                return None
                
        except Exception as e:
            print(f"Error fetching NASA POWER daily data: {e}")
            return None

    def _extract_point_data(self, file_url, target_lat, target_lon, variables):
        """Extract data for a specific point from GLDAS NetCDF file"""
        
        try:
            # Use requests with authentication
            session = requests.Session()
            session.auth = (self.username, self.password)
            
            # For demo, we'll simulate the NetCDF data extraction
            # In practice, you'd use xarray or netCDF4 to read from OPeNDAP
            
            print(f"🔄 Processing: {file_url.split('/')[-1]}")
            
            # Extract timestamp from filename
            filename = file_url.split('/')[-1]
            date_part = filename.split('.')[1]  
            
            year = int(date_part[1:5])
            month = int(date_part[5:7])
            day = int(date_part[7:9])
            
            timestamp = datetime(year, month, day)
            
            # This is where you'd actually read from the NetCDF file
            # For now, using NASA POWER API as a real data source
            data = self._get_nasa_power_data(target_lat, target_lon, timestamp, variables)
            
            return data
            
        except Exception as e:
            print(f"Error extracting point data: {e}")
            return None
    
    def _get_nasa_power_data(self, lat, lon, timestamp, variables):
        """Get data from NASA POWER API as fallback"""
        
        try:
            # NASA POWER API for real meteorological data
            base_url = "https://power.larc.nasa.gov/api/temporal/hourly/point"
            
            # Map our variables to POWER parameters
            power_params = []
            if 'temp' in variables:
                power_params.append('T2M')  # Temperature at 2m
            if 'humidity' in variables:
                power_params.append('QV2M')  # Specific humidity at 2m
            if 'pressure' in variables:
                power_params.append('PS')   # Surface pressure
            if 'precipitation' in variables:
                power_params.append('PRECTOT')  # Precipitation
            if 'solar_rad' in variables:
                power_params.append('ALLSKY_SFC_SW_DWN')  # Solar radiation
            if 'wind_u' in variables:
                power_params.append('WS2M')
            
            if not power_params:
                return None
            
            params = {
                'parameters': ','.join(power_params),
                'community': 'RE',
                'longitude': lon,
                'latitude': lat,
                'start': timestamp.strftime('%Y%m%d'),
                'end': timestamp.strftime('%Y%m%d'),
                'format': 'JSON'
            }
            
            # Make request to NASA POWER
            response = requests.get(base_url, params=params, timeout=30)
            
            if response.status_code == 200:
                data = response.json()
                
                # Extract the data for our timestamp
                record = {
                    'datetime': timestamp,
                    'latitude': lat,
                    'longitude': lon
                }
               
                return record
            else:
                print(f"NASA POWER API error: {response.status_code}")
                return None
                
        except Exception as e:
            print(f"Error fetching NASA POWER data: {e}")
            return None
    
    def get_bulk_data(self, locations, start_date, end_date, variables=None):
        
        """Fetch data for multiple locations"""
        try:
            data = self.get_data(lat, lon, start_date, end_date, variables)
            if not data.empty:
                location_key = f"lat_{lat}_lon_{lon}"
                results[location_key] = data
                print(f"✅ Success: {len(data)} records")
            else:
                print(f"❌ No data retrieved")
                    
        except Exception as e:
            print(f"❌ Error: {e}")
            
        
        return results
    
    def to_csv(self, data, filename):
        """Export data to CSV"""
        if isinstance(data, dict):
            all_data = []
            for location_key, df in data.items():
                df_copy = df.reset_index()
                df_copy['location'] = location_key
                all_data.append(df_copy)
            
            combined_df = pd.concat(all_data, ignore_index=True)
            combined_df.to_csv(filename, index=False)
        else:
            data.to_csv(filename)
            
        print(f"💾 Data exported to {filename}")

# %%
def main():
    """Example usage with NASA data"""
    
    print("🚀 NASA GLDAS Data Fetcher")
    print("=" * 50)
    
    
    username = "mahmoudmo12"
    password = "Mahmoudmetawe12@"
    

    # Initialize with real credentials
    fetcher = GLDASFetcher(username=username, password=password)
    city = input("enter the city: ")
    # Test with a single location
    print(f"\n🌍 Fetching DAILY data for {city} City...")
    
    data = fetcher.get_data(
        lat=30.0444,
        lon=31.2358,
        start_date="2004-01-01",
        end_date="2025-09-15",
        variables=['temp', 'humidity', 'pressure', 'precipitation', 'solar_rad', 'wind_speed']
    )
    
    if not data.empty:
        print(f"\n✅ SUCCESS! Retrieved {len(data)} real data points")
        print(f"📋 Columns: {list(data.columns)}")
        
        # Export real data
        fetcher.to_csv(data, "nasa_daily_weather_data.csv")
    else:
        print("❌")

if __name__ == "__main__":
    main()
# Out:
# 🚀 NASA GLDAS Data Fetcher
# ==================================================
# enter the city:  cairo
# 🌍 Fetching DAILY data for cairo City...
# 🌍 Fetching GLDAS DAILY data from NASA
# 📍 Location: (30.0444, 31.2358)
# 📅 Dates: 2004-01-01 to 2025-09-15
# 📊 Variables: ['temp', 'humidity', 'pressure', 'precipitation', 'solar_rad', 'wind_speed']
# 🗂️ Dataset: Daily aggregated
# 🔄 Fetching daily data for: 2004-01-01
# 🔄 Fetching daily data for: 2004-01-02
# 🔄 Fetching daily data for: 2004-01-03
# 🔄 Fetching daily data for: 2004-01-04
# 🔄 Fetching daily data for: 2004-01-05
# 🔄 Fetching daily data for: 2004-01-06
# 🔄 Fetching daily data for: 2004-01-07
# 🔄 Fetching daily data for: 2004-01-08
# 🔄 Fetching daily data for: 2004-01-09
# 🔄 Fetching daily data for: 2004-01-10
# 🔄 Fetching daily data for: 2004-01-11
# 🔄 Fetching daily data for: 2004-01-12
# 🔄 Fetching daily data for: 2004-01-13
# 🔄 Fetching daily data for: 2004-01-14
# 🔄 Fetching daily data for: 2004-01-15
# 🔄 Fetching daily data for: 2004-01-16
# 🔄 Fetching daily data for: 2004-01-17
# 🔄 Fetching daily data for: 2004-01-18
# 🔄 Fetching daily data for: 2004-01-19
# 🔄 Fetching daily data for: 2004-01-20
# 🔄 Fetching daily data for: 2004-01-21
# 🔄 Fetching daily data for: 2004-01-22
# 🔄 Fetching daily data for: 2004-01-23
# 🔄 Fetching daily data for: 2004-01-24
# 🔄 Fetching daily data for: 2004-01-25
# 🔄 Fetching daily data for: 2004-01-26
# 🔄 Fetching daily data for: 2004-01-27
# 🔄 Fetching daily data for: 2004-01-28
# 🔄 Fetching daily data for: 2004-01-29
# 🔄 Fetching daily data for: 2004-01-30
# 🔄 Fetching daily data for: 2004-01-31
# 🔄 Fetching daily data for: 2004-02-01
# 🔄 Fetching daily data for: 2004-02-02
# 🔄 Fetching daily data for: 2004-02-03
# 🔄 Fetching daily data for: 2004-02-04
# 🔄 Fetching daily data for: 2004-02-05
# 🔄 Fetching daily data for: 2004-02-06
# 🔄 Fetching daily data for: 2004-02-07
# 🔄 Fetching daily data for: 2004-02-08
# 🔄 Fetching daily data for: 2004-06-20
# 🔄 Fetching daily data for: 2004-06-21
# 🔄 Fetching daily data for: 2004-06-22
# 🔄 Fetching daily data for: 2004-06-23
# 🔄 Fetching daily data for: 2004-06-24
# 🔄 Fetching daily data for: 2004-06-25
# 🔄 Fetching daily data for: 2004-06-26
# 🔄 Fetching daily data for: 2004-06-27
# 🔄 Fetching daily data for: 2004-06-28
# 🔄 Fetching daily data for: 2004-06-29
# 🔄 Fetching daily data for: 2004-06-30
# 🔄 Fetching daily data for: 2004-07-01
# 🔄 Fetching daily data for: 2004-07-02
# 🔄 Fetching daily data for: 2004-07-03
# 🔄 Fetching daily data for: 2004-07-04
# 🔄 Fetching daily data for: 2004-07-05
# 🔄 Fetching daily data for: 2004-07-06
# 🔄 Fetching daily data for: 2004-07-07
# 🔄 Fetching daily data for: 2004-07-08
# 🔄 Fetching daily data for: 2004-07-09
# 🔄 Fetching daily data for: 2004-07-10
# 🔄 Fetching daily data for: 2004-07-11
# 🔄 Fetching daily data for: 2004-07-12
# 🔄 Fetching daily data for: 2004-07-13
# 🔄 Fetching daily data for: 2004-07-14
# 🔄 Fetching daily data for: 2004-07-15
# 🔄 Fetching daily data for: 2004-07-16
# 🔄 Fetching daily data for: 2004-07-17
# 🔄 Fetching daily data for: 2004-07-18
# 🔄 Fetching daily data for: 2004-07-19
# 🔄 Fetching daily data for: 2004-07-20
# 🔄 Fetching daily data for: 2004-07-21
# 🔄 Fetching daily data for: 2004-07-22
# 🔄 Fetching daily data for: 2004-07-23
# 🔄 Fetching daily data for: 2004-07-24
# 🔄 Fetching daily data for: 2004-07-25
# 🔄 Fetching daily data for: 2004-07-26
# 🔄 Fetching daily data for: 2004-07-27
# 🔄 Fetching daily data for: 2004-07-28
# 🔄 Fetching daily data for: 2004-07-29
# 🔄 Fetching daily data for: 2004-07-30
# 🔄 Fetching daily data for: 2004-07-31
# 🔄 Fetching daily data for: 2004-08-01
# 🔄 Fetching daily data for: 2004-08-02
# 🔄 Fetching daily data for: 2004-08-03
# 🔄 Fetching daily data for: 2004-08-04
# 🔄 Fetching daily data for: 2004-08-05
# 🔄 Fetching daily data for: 2004-08-06
# 🔄 Fetching daily data for: 2004-08-07
# 🔄 Fetching daily data for: 2004-08-08
# 🔄 Fetching daily data for: 2004-08-09
# 🔄 Fetching daily data for: 2004-08-10
# 🔄 Fetching daily data for: 2004-08-11
# 🔄 Fetching daily data for: 2004-08-12
# 🔄 Fetching daily data for: 2004-08-13
# 🔄 Fetching daily data for: 2004-08-14
# 🔄 Fetching daily data for: 2004-08-15
# 🔄 Fetching daily data for: 2004-08-16
# 🔄 Fetching daily data for: 2004-08-17
# 🔄 Fetching daily data for: 2004-08-18
# 🔄 Fetching daily data for: 2004-08-19
# 🔄 Fetching daily data for: 2004-08-20
# 🔄 Fetching daily data for: 2004-08-21
# 🔄 Fetching daily data for: 2004-08-22
# 🔄 Fetching daily data for: 2004-08-23
# 🔄 Fetching daily data for: 2004-08-24
# 🔄 Fetching daily data for: 2004-08-25
# 🔄 Fetching daily data for: 2004-08-26
# 🔄 Fetching daily data for: 2004-08-27
# 🔄 Fetching daily data for: 2004-08-28
# 🔄 Fetching daily data for: 2004-08-29
# 🔄 Fetching daily data for: 2004-08-30
# 🔄 Fetching daily data for: 2004-08-31
# 🔄 Fetching daily data for: 2004-09-01
# 🔄 Fetching daily data for: 2004-09-02
# 🔄 Fetching daily data for: 2004-09-03
# 🔄 Fetching daily data for: 2004-09-04
# 🔄 Fetching daily data for: 2004-09-05
# 🔄 Fetching daily data for: 2004-09-06
# 🔄 Fetching daily data for: 2004-09-07
# 🔄 Fetching daily data for: 2004-09-08
# 🔄 Fetching daily data for: 2004-09-09
# 🔄 Fetching daily data for: 2004-09-10
# 🔄 Fetching daily data for: 2004-09-11
# 🔄 Fetching daily data for: 2004-09-12
# 🔄 Fetching daily data for: 2004-09-13
# 🔄 Fetching daily data for: 2004-09-14
# 🔄 Fetching daily data for: 2004-09-15
# 🔄 Fetching daily data for: 2004-09-16
# 🔄 Fetching daily data for: 2004-09-17
# 🔄 Fetching daily data for: 2004-09-18
# 🔄 Fetching daily data for: 2004-09-19
# 🔄 Fetching daily data for: 2004-09-20
# 🔄 Fetching daily data for: 2004-09-21
# 🔄 Fetching daily data for: 2004-09-22
# 🔄 Fetching daily data for: 2004-09-23
# 🔄 Fetching daily data for: 2004-09-24
# 🔄 Fetching daily data for: 2004-09-25
# 🔄 Fetching daily data for: 2004-09-26
# 🔄 Fetching daily data for: 2004-09-27
# 🔄 Fetching daily data for: 2004-09-28
# 🔄 Fetching daily data for: 2004-09-29
# 🔄 Fetching daily data for: 2004-09-30
# 🔄 Fetching daily data for: 2004-10-01
# 🔄 Fetching daily data for: 2004-10-02
# 🔄 Fetching daily data for: 2004-10-03
# 🔄 Fetching daily data for: 2004-10-04
# 🔄 Fetching daily data for: 2004-10-05
# 🔄 Fetching daily data for: 2004-10-06
# 🔄 Fetching daily data for: 2004-10-07
# 🔄 Fetching daily data for: 2004-10-08
# 🔄 Fetching daily data for: 2004-10-09
# 🔄 Fetching daily data for: 2004-10-10
# 🔄 Fetching daily data for: 2004-10-11
# 🔄 Fetching daily data for: 2004-10-12
# 🔄 Fetching daily data for: 2004-10-13
# 🔄 Fetching daily data for: 2004-10-14
# 🔄 Fetching daily data for: 2004-10-15
# 🔄 Fetching daily data for: 2004-10-16
# 🔄 Fetching daily data for: 2004-10-17
# 🔄 Fetching daily data for: 2004-10-18
# 🔄 Fetching daily data for: 2004-10-19
# 🔄 Fetching daily data for: 2004-10-20
# 🔄 Fetching daily data for: 2004-10-21
# 🔄 Fetching daily data for: 2004-10-22
# 🔄 Fetching daily data for: 2004-10-23
# 🔄 Fetching daily data for: 2004-10-24
# 🔄 Fetching daily data for: 2004-10-25
# 🔄 Fetching daily data for: 2004-10-26
# 🔄 Fetching daily data for: 2004-10-27
# 🔄 Fetching daily data for: 2004-10-28
# 🔄 Fetching daily data for: 2005-01-02
# 🔄 Fetching daily data for: 2005-01-03
# 🔄 Fetching daily data for: 2005-01-04
# 🔄 Fetching daily data for: 2005-01-05
# 🔄 Fetching daily data for: 2005-01-06
# 🔄 Fetching daily data for: 2005-01-07
# 🔄 Fetching daily data for: 2005-01-08
# 🔄 Fetching daily data for: 2005-01-09
# 🔄 Fetching daily data for: 2005-01-10
# 🔄 Fetching daily data for: 2005-01-11
# 🔄 Fetching daily data for: 2005-01-12
# 🔄 Fetching daily data for: 2005-01-13
# 🔄 Fetching daily data for: 2005-01-14
# 🔄 Fetching daily data for: 2005-01-15
# 🔄 Fetching daily data for: 2005-01-16
# 🔄 Fetching daily data for: 2005-01-17
# 🔄 Fetching daily data for: 2005-01-18
# 🔄 Fetching daily data for: 2005-01-19
# 🔄 Fetching daily data for: 2005-01-20
# 🔄 Fetching daily data for: 2005-01-21
# 🔄 Fetching daily data for: 2005-01-22
# 🔄 Fetching daily data for: 2005-01-23
# 🔄 Fetching daily data for: 2005-01-24
# 🔄 Fetching daily data for: 2005-01-25
# 🔄 Fetching daily data for: 2005-01-26
# 🔄 Fetching daily data for: 2005-01-27
# 🔄 Fetching daily data for: 2005-01-28
# 🔄 Fetching daily data for: 2005-01-29
# 🔄 Fetching daily data for: 2005-01-30
# 🔄 Fetching daily data for: 2005-01-31
# 🔄 Fetching daily data for: 2005-02-01
# 🔄 Fetching daily data for: 2005-02-02
# 🔄 Fetching daily data for: 2005-02-03
# 🔄 Fetching daily data for: 2005-02-04
# 🔄 Fetching daily data for: 2005-02-05
# 🔄 Fetching daily data for: 2005-02-06
# 🔄 Fetching daily data for: 2005-02-07
# 🔄 Fetching daily data for: 2005-02-08
# 🔄 Fetching daily data for: 2005-02-09
# 🔄 Fetching daily data for: 2005-02-10
# 🔄 Fetching daily data for: 2005-02-11
# 🔄 Fetching daily data for: 2005-02-12
# 🔄 Fetching daily data for: 2005-02-13
# 🔄 Fetching daily data for: 2005-02-14
# 🔄 Fetching daily data for: 2005-02-15
# 🔄 Fetching daily data for: 2005-02-16
# 🔄 Fetching daily data for: 2005-02-17
# 🔄 Fetching daily data for: 2005-02-18
# 🔄 Fetching daily data for: 2005-02-19
# 🔄 Fetching daily data for: 2005-02-20
# 🔄 Fetching daily data for: 2005-02-21
# 🔄 Fetching daily data for: 2005-02-22
# 🔄 Fetching daily data for: 2005-02-23
# 🔄 Fetching daily data for: 2005-02-24
# 🔄 Fetching daily data for: 2005-02-25
# 🔄 Fetching daily data for: 2005-02-26
# 🔄 Fetching daily data for: 2005-02-27
# 🔄 Fetching daily data for: 2005-02-28
# 🔄 Fetching daily data for: 2005-03-01
# 🔄 Fetching daily data for: 2005-03-02
# 🔄 Fetching daily data for: 2005-03-03
# 🔄 Fetching daily data for: 2005-03-04
# 🔄 Fetching daily data for: 2005-03-05
# 🔄 Fetching daily data for: 2005-03-06
# 🔄 Fetching daily data for: 2005-03-07
# 🔄 Fetching daily data for: 2005-03-08
# 🔄 Fetching daily data for: 2005-05-14
# 🔄 Fetching daily data for: 2005-05-15
# 🔄 Fetching daily data for: 2005-05-16
# 🔄 Fetching daily data for: 2005-05-17
# 🔄 Fetching daily data for: 2005-05-18
# 🔄 Fetching daily data for: 2005-05-19
# 🔄 Fetching daily data for: 2005-05-20
# 🔄 Fetching daily data for: 2005-05-21
# 🔄 Fetching daily data for: 2005-05-22
# 🔄 Fetching daily data for: 2005-05-23
# 🔄 Fetching daily data for: 2005-05-24
# 🔄 Fetching daily data for: 2005-05-25
# 🔄 Fetching daily data for: 2005-05-26
# 🔄 Fetching daily data for: 2005-05-27
# 🔄 Fetching daily data for: 2005-05-28
# 🔄 Fetching daily data for: 2005-05-29
# 🔄 Fetching daily data for: 2005-05-30
# 🔄 Fetching daily data for: 2005-05-31
# 🔄 Fetching daily data for: 2005-06-01
# 🔄 Fetching daily data for: 2005-06-02
# 🔄 Fetching daily data for: 2005-06-03
# 🔄 Fetching daily data for: 2005-06-04
# 🔄 Fetching daily data for: 2005-06-05
# 🔄 Fetching daily data for: 2005-06-06
# 🔄 Fetching daily data for: 2005-06-07
# 🔄 Fetching daily data for: 2005-06-08
# 🔄 Fetching daily data for: 2005-06-09
# 🔄 Fetching daily data for: 2005-06-10
# 🔄 Fetching daily data for: 2005-06-11
# 🔄 Fetching daily data for: 2005-06-12
# 🔄 Fetching daily data for: 2005-06-13
# 🔄 Fetching daily data for: 2005-06-14
# 🔄 Fetching daily data for: 2005-06-15
# 🔄 Fetching daily data for: 2005-06-16
# 🔄 Fetching daily data for: 2005-06-17
# 🔄 Fetching daily data for: 2005-06-18
# 🔄 Fetching daily data for: 2005-06-19
# 🔄 Fetching daily data for: 2005-06-20
# 🔄 Fetching daily data for: 2005-06-21
# 🔄 Fetching daily data for: 2005-06-22
# 🔄 Fetching daily data for: 2005-06-23
# 🔄 Fetching daily data for: 2005-06-24
# 🔄 Fetching daily data for: 2005-06-25
# 🔄 Fetching daily data for: 2005-06-26
# 🔄 Fetching daily data for: 2005-06-27
# 🔄 Fetching daily data for: 2005-06-28
# 🔄 Fetching daily data for: 2005-06-29
# 🔄 Fetching daily data for: 2005-06-30
# 🔄 Fetching daily data for: 2005-07-01
# 🔄 Fetching daily data for: 2005-07-02
# 🔄 Fetching daily data for: 2005-07-03
# 🔄 Fetching daily data for: 2005-07-04
# 🔄 Fetching daily data for: 2005-07-05
# 🔄 Fetching daily data for: 2005-07-06
# 🔄 Fetching daily data for: 2005-07-07
# 🔄 Fetching daily data for: 2005-07-08
# 🔄 Fetching daily data for: 2005-07-09
# 🔄 Fetching daily data for: 2005-07-10
# 🔄 Fetching daily data for: 2005-07-11
# 🔄 Fetching daily data for: 2005-07-12
# 🔄 Fetching daily data for: 2005-07-13
# 🔄 Fetching daily data for: 2005-07-14
# 🔄 Fetching daily data for: 2005-07-15
# 🔄 Fetching daily data for: 2005-07-16
# 🔄 Fetching daily data for: 2005-07-17
# 🔄 Fetching daily data for: 2005-07-18
# 🔄 Fetching daily data for: 2005-07-19
# 🔄 Fetching daily data for: 2005-07-20
# 🔄 Fetching daily data for: 2005-07-21
# 🔄 Fetching daily data for: 2005-07-22
# 🔄 Fetching daily data for: 2005-07-23
# 🔄 Fetching daily data for: 2005-07-24
# 🔄 Fetching daily data for: 2005-07-25
# 🔄 Fetching daily data for: 2005-07-26
# 🔄 Fetching daily data for: 2005-07-27
# 🔄 Fetching daily data for: 2005-07-28
# 🔄 Fetching daily data for: 2005-07-29
# 🔄 Fetching daily data for: 2005-07-30
# 🔄 Fetching daily data for: 2005-07-31
# 🔄 Fetching daily data for: 2005-08-01
# 🔄 Fetching daily data for: 2005-08-02
# 🔄 Fetching daily data for: 2005-08-03
# 🔄 Fetching daily data for: 2005-08-04
# 🔄 Fetching daily data for: 2005-08-05
# 🔄 Fetching daily data for: 2005-08-06
# 🔄 Fetching daily data for: 2005-08-07
# 🔄 Fetching daily data for: 2005-08-08
# 🔄 Fetching daily data for: 2005-08-09
# 🔄 Fetching daily data for: 2005-08-10
# 🔄 Fetching daily data for: 2005-08-11
# 🔄 Fetching daily data for: 2005-08-12
# 🔄 Fetching daily data for: 2005-08-13
# 🔄 Fetching daily data for: 2005-08-14
# 🔄 Fetching daily data for: 2005-08-15
# 🔄 Fetching daily data for: 2005-08-16
# 🔄 Fetching daily data for: 2005-08-17
# 🔄 Fetching daily data for: 2005-08-18
# 🔄 Fetching daily data for: 2005-08-19
# 🔄 Fetching daily data for: 2005-08-20
# 🔄 Fetching daily data for: 2005-08-21
# 🔄 Fetching daily data for: 2005-08-22
# 🔄 Fetching daily data for: 2005-08-23
# 🔄 Fetching daily data for: 2005-08-24
# 🔄 Fetching daily data for: 2005-08-25
# 🔄 Fetching daily data for: 2005-08-26
# 🔄 Fetching daily data for: 2005-08-27
# 🔄 Fetching daily data for: 2005-08-28
# 🔄 Fetching daily data for: 2005-08-29
# 🔄 Fetching daily data for: 2005-08-30
# 🔄 Fetching daily data for: 2005-08-31
# 🔄 Fetching daily data for: 2005-09-01
# 🔄 Fetching daily data for: 2005-09-02
# 🔄 Fetching daily data for: 2005-09-03
# 🔄 Fetching daily data for: 2005-09-04
# 🔄 Fetching daily data for: 2005-09-05
# 🔄 Fetching daily data for: 2005-09-06
# 🔄 Fetching daily data for: 2005-09-07
# 🔄 Fetching daily data for: 2005-09-08
# 🔄 Fetching daily data for: 2005-09-09
# 🔄 Fetching daily data for: 2005-09-10
# 🔄 Fetching daily data for: 2005-09-11
# 🔄 Fetching daily data for: 2005-09-12
# 🔄 Fetching daily data for: 2005-09-13
# 🔄 Fetching daily data for: 2005-09-14
# 🔄 Fetching daily data for: 2005-09-15
# 🔄 Fetching daily data for: 2005-09-16
# 🔄 Fetching daily data for: 2005-09-17
# 🔄 Fetching daily data for: 2005-09-18
# 🔄 Fetching daily data for: 2005-09-19
# 🔄 Fetching daily data for: 2005-09-20
# 🔄 Fetching daily data for: 2005-09-21
# 🔄 Fetching daily data for: 2005-09-22
# 🔄 Fetching daily data for: 2005-09-23
# 🔄 Fetching daily data for: 2005-09-24
# 🔄 Fetching daily data for: 2005-09-25
# 🔄 Fetching daily data for: 2005-09-26
# 🔄 Fetching daily data for: 2005-09-27
# 🔄 Fetching daily data for: 2005-09-28
# 🔄 Fetching daily data for: 2005-09-29
# 🔄 Fetching daily data for: 2005-09-30
# 🔄 Fetching daily data for: 2005-10-01
# 🔄 Fetching daily data for: 2005-10-02
# 🔄 Fetching daily data for: 2005-10-03
# 🔄 Fetching daily data for: 2005-10-04
# 🔄 Fetching daily data for: 2005-10-05
# 🔄 Fetching daily data for: 2005-10-06
# 🔄 Fetching daily data for: 2005-10-07
# 🔄 Fetching daily data for: 2005-10-08
# 🔄 Fetching daily data for: 2005-10-09
# 🔄 Fetching daily data for: 2005-10-10
# 🔄 Fetching daily data for: 2005-10-11
# 🔄 Fetching daily data for: 2005-10-12
# 🔄 Fetching daily data for: 2005-10-13
# 🔄 Fetching daily data for: 2005-10-14
# 🔄 Fetching daily data for: 2005-10-15
# 🔄 Fetching daily data for: 2005-10-16
# 🔄 Fetching daily data for: 2005-10-17
# 🔄 Fetching daily data for: 2005-10-18
# 🔄 Fetching daily data for: 2005-10-19
# 🔄 Fetching daily data for: 2005-10-20
# 🔄 Fetching daily data for: 2005-10-21
# 🔄 Fetching daily data for: 2005-10-22
# 🔄 Fetching daily data for: 2005-10-23
# 🔄 Fetching daily data for: 2005-10-24
# 🔄 Fetching daily data for: 2005-10-25
# 🔄 Fetching daily data for: 2005-10-26
# 🔄 Fetching daily data for: 2005-10-27
# 🔄 Fetching daily data for: 2005-10-28
# 🔄 Fetching daily data for: 2005-10-29
# 🔄 Fetching daily data for: 2005-10-30
# 🔄 Fetching daily data for: 2005-10-31
# 🔄 Fetching daily data for: 2005-11-01
# 🔄 Fetching daily data for: 2005-11-02
# 🔄 Fetching daily data for: 2005-11-03
# 🔄 Fetching daily data for: 2005-11-04
# 🔄 Fetching daily data for: 2005-11-05
# 🔄 Fetching daily data for: 2005-11-06
# 🔄 Fetching daily data for: 2005-11-07
# 🔄 Fetching daily data for: 2005-11-08
# 🔄 Fetching daily data for: 2005-11-09
# 🔄 Fetching daily data for: 2005-11-10
# 🔄 Fetching daily data for: 2005-11-11
# 🔄 Fetching daily data for: 2005-11-12
# 🔄 Fetching daily data for: 2005-11-13
# 🔄 Fetching daily data for: 2005-11-14
# 🔄 Fetching daily data for: 2005-11-15
# 🔄 Fetching daily data for: 2005-11-16
# 🔄 Fetching daily data for: 2005-11-17
# 🔄 Fetching daily data for: 2005-11-18
# 🔄 Fetching daily data for: 2005-11-19
# 🔄 Fetching daily data for: 2005-11-20
# 🔄 Fetching daily data for: 2005-11-21
# 🔄 Fetching daily data for: 2005-11-22
# 🔄 Fetching daily data for: 2005-11-23
# 🔄 Fetching daily data for: 2005-11-24
# 🔄 Fetching daily data for: 2005-11-25
# 🔄 Fetching daily data for: 2005-11-26
# 🔄 Fetching daily data for: 2006-06-11
# 🔄 Fetching daily data for: 2006-06-12
# 🔄 Fetching daily data for: 2006-06-13
# 🔄 Fetching daily data for: 2006-06-14
# 🔄 Fetching daily data for: 2006-06-15
# 🔄 Fetching daily data for: 2006-06-16
# 🔄 Fetching daily data for: 2006-06-17
# 🔄 Fetching daily data for: 2006-06-18
# 🔄 Fetching daily data for: 2006-06-19
# 🔄 Fetching daily data for: 2006-06-20
# 🔄 Fetching daily data for: 2006-06-21
# 🔄 Fetching daily data for: 2006-06-22
# 🔄 Fetching daily data for: 2006-06-23
# 🔄 Fetching daily data for: 2006-06-24
# 🔄 Fetching daily data for: 2006-06-25
# 🔄 Fetching daily data for: 2006-06-26
# 🔄 Fetching daily data for: 2006-06-27
# 🔄 Fetching daily data for: 2006-06-28
# 🔄 Fetching daily data for: 2006-06-29
# 🔄 Fetching daily data for: 2006-06-30
# 🔄 Fetching daily data for: 2006-07-01
# 🔄 Fetching daily data for: 2006-07-02
# 🔄 Fetching daily data for: 2006-07-03
# 🔄 Fetching daily data for: 2006-07-04
# 🔄 Fetching daily data for: 2006-07-05
# 🔄 Fetching daily data for: 2006-07-06
# 🔄 Fetching daily data for: 2006-07-07
# 🔄 Fetching daily data for: 2006-07-08
# 🔄 Fetching daily data for: 2006-07-09
# 🔄 Fetching daily data for: 2006-07-10
# 🔄 Fetching daily data for: 2006-07-11
# 🔄 Fetching daily data for: 2006-07-12
# 🔄 Fetching daily data for: 2006-07-13
# 🔄 Fetching daily data for: 2006-07-14
# 🔄 Fetching daily data for: 2006-07-15
# 🔄 Fetching daily data for: 2006-07-16
# 🔄 Fetching daily data for: 2006-07-17
# 🔄 Fetching daily data for: 2006-07-18
# 🔄 Fetching daily data for: 2006-07-19
# 🔄 Fetching daily data for: 2006-07-20
# 🔄 Fetching daily data for: 2006-07-21
# 🔄 Fetching daily data for: 2006-07-22
# 🔄 Fetching daily data for: 2006-07-23
# 🔄 Fetching daily data for: 2006-07-24
# 🔄 Fetching daily data for: 2006-07-25
# 🔄 Fetching daily data for: 2006-07-26
# 🔄 Fetching daily data for: 2006-07-27
# 🔄 Fetching daily data for: 2006-07-28
# 🔄 Fetching daily data for: 2006-07-29
# 🔄 Fetching daily data for: 2006-07-30
# 🔄 Fetching daily data for: 2006-07-31
# 🔄 Fetching daily data for: 2006-08-01
# 🔄 Fetching daily data for: 2006-08-02
# 🔄 Fetching daily data for: 2006-08-03
# 🔄 Fetching daily data for: 2006-08-04
# 🔄 Fetching daily data for: 2006-08-05
# 🔄 Fetching daily data for: 2006-08-06
# 🔄 Fetching daily data for: 2006-08-07
# 🔄 Fetching daily data for: 2006-08-08
# 🔄 Fetching daily data for: 2006-08-09
# 🔄 Fetching daily data for: 2006-08-10
# 🔄 Fetching daily data for: 2006-08-11
# 🔄 Fetching daily data for: 2006-08-12
# 🔄 Fetching daily data for: 2006-08-13
# 🔄 Fetching daily data for: 2006-08-14
# 🔄 Fetching daily data for: 2006-08-15
# 🔄 Fetching daily data for: 2006-08-16
# 🔄 Fetching daily data for: 2006-08-17
# 🔄 Fetching daily data for: 2006-08-18
# 🔄 Fetching daily data for: 2006-08-19
# 🔄 Fetching daily data for: 2006-08-20
# 🔄 Fetching daily data for: 2006-08-21
# 🔄 Fetching daily data for: 2006-08-22
# 🔄 Fetching daily data for: 2006-08-23
# 🔄 Fetching daily data for: 2006-08-24
# 🔄 Fetching daily data for: 2006-08-25
# 🔄 Fetching daily data for: 2006-08-26
# 🔄 Fetching daily data for: 2006-08-27
# 🔄 Fetching daily data for: 2006-08-28
# 🔄 Fetching daily data for: 2006-08-29
# 🔄 Fetching daily data for: 2006-08-30
# 🔄 Fetching daily data for: 2006-08-31
# 🔄 Fetching daily data for: 2006-09-01
# 🔄 Fetching daily data for: 2006-09-02
# 🔄 Fetching daily data for: 2006-09-03
# 🔄 Fetching daily data for: 2006-09-04
# 🔄 Fetching daily data for: 2006-09-05
# 🔄 Fetching daily data for: 2006-09-06
# 🔄 Fetching daily data for: 2006-09-07
# 🔄 Fetching daily data for: 2006-09-08
# 🔄 Fetching daily data for: 2006-09-09
# 🔄 Fetching daily data for: 2006-09-10
# 🔄 Fetching daily data for: 2006-09-11
# 🔄 Fetching daily data for: 2006-09-12
# 🔄 Fetching daily data for: 2006-09-13
# 🔄 Fetching daily data for: 2006-09-14
# 🔄 Fetching daily data for: 2006-09-15
# 🔄 Fetching daily data for: 2006-09-16
# 🔄 Fetching daily data for: 2006-09-17
# 🔄 Fetching daily data for: 2006-09-18
# 🔄 Fetching daily data for: 2006-09-19
# 🔄 Fetching daily data for: 2006-09-20
# 🔄 Fetching daily data for: 2006-09-21
# 🔄 Fetching daily data for: 2006-09-22
# 🔄 Fetching daily data for: 2006-09-23
# 🔄 Fetching daily data for: 2006-09-24
# 🔄 Fetching daily data for: 2006-09-25
# 🔄 Fetching daily data for: 2006-09-26
# 🔄 Fetching daily data for: 2006-09-27
# 🔄 Fetching daily data for: 2006-09-28
# 🔄 Fetching daily data for: 2006-09-29
# 🔄 Fetching daily data for: 2006-09-30
# 🔄 Fetching daily data for: 2006-10-01
# 🔄 Fetching daily data for: 2006-10-02
# 🔄 Fetching daily data for: 2006-10-03
# 🔄 Fetching daily data for: 2006-10-04
# 🔄 Fetching daily data for: 2006-10-05
# 🔄 Fetching daily data for: 2006-10-06
# 🔄 Fetching daily data for: 2006-10-07
# 🔄 Fetching daily data for: 2006-10-08
# 🔄 Fetching daily data for: 2006-10-09
# 🔄 Fetching daily data for: 2006-10-10
# 🔄 Fetching daily data for: 2006-10-11
# 🔄 Fetching daily data for: 2006-10-12
# 🔄 Fetching daily data for: 2006-10-13
# 🔄 Fetching daily data for: 2006-10-14
# 🔄 Fetching daily data for: 2006-10-15
# 🔄 Fetching daily data for: 2006-10-16
# 🔄 Fetching daily data for: 2006-10-17
# 🔄 Fetching daily data for: 2006-10-18
# 🔄 Fetching daily data for: 2006-10-19
# 🔄 Fetching daily data for: 2006-10-20
# 🔄 Fetching daily data for: 2006-10-21
# 🔄 Fetching daily data for: 2006-10-22
# 🔄 Fetching daily data for: 2006-10-23
# 🔄 Fetching daily data for: 2006-10-24
# 🔄 Fetching daily data for: 2006-10-25
# 🔄 Fetching daily data for: 2006-10-26
# 🔄 Fetching daily data for: 2006-10-27
# 🔄 Fetching daily data for: 2006-10-28
# 🔄 Fetching daily data for: 2006-10-29
# 🔄 Fetching daily data for: 2006-10-30
# 🔄 Fetching daily data for: 2006-10-31
# 🔄 Fetching daily data for: 2006-11-01
# 🔄 Fetching daily data for: 2006-11-02
# 🔄 Fetching daily data for: 2006-11-03
# 🔄 Fetching daily data for: 2006-11-04
# 🔄 Fetching daily data for: 2006-11-05
# 🔄 Fetching daily data for: 2006-11-06
# 🔄 Fetching daily data for: 2006-11-07
# 🔄 Fetching daily data for: 2006-11-08
# 🔄 Fetching daily data for: 2006-11-09
# 🔄 Fetching daily data for: 2006-11-10
# 🔄 Fetching daily data for: 2006-11-11
# 🔄 Fetching daily data for: 2006-11-12
# 🔄 Fetching daily data for: 2006-11-13
# 🔄 Fetching daily data for: 2006-11-14
# 🔄 Fetching daily data for: 2006-11-15
# 🔄 Fetching daily data for: 2006-11-16
# 🔄 Fetching daily data for: 2006-11-17
# 🔄 Fetching daily data for: 2006-11-18
# 🔄 Fetching daily data for: 2006-11-19
# 🔄 Fetching daily data for: 2006-11-20
# 🔄 Fetching daily data for: 2006-11-21
# 🔄 Fetching daily data for: 2006-11-22
# 🔄 Fetching daily data for: 2006-11-23
# 🔄 Fetching daily data for: 2006-11-24
# 🔄 Fetching daily data for: 2006-11-25
# 🔄 Fetching daily data for: 2006-11-26
# 🔄 Fetching daily data for: 2006-11-27
# 🔄 Fetching daily data for: 2006-11-28
# 🔄 Fetching daily data for: 2006-11-29
# 🔄 Fetching daily data for: 2006-11-30
# 🔄 Fetching daily data for: 2006-12-01
# 🔄 Fetching daily data for: 2006-12-02
# 🔄 Fetching daily data for: 2006-12-03
# 🔄 Fetching daily data for: 2006-12-04
# 🔄 Fetching daily data for: 2006-12-05
# 🔄 Fetching daily data for: 2006-12-06
# 🔄 Fetching daily data for: 2006-12-07
# 🔄 Fetching daily data for: 2006-12-08
# 🔄 Fetching daily data for: 2006-12-09
# 🔄 Fetching daily data for: 2006-12-10
# 🔄 Fetching daily data for: 2006-12-11
# 🔄 Fetching daily data for: 2006-12-12
# 🔄 Fetching daily data for: 2006-12-13
# 🔄 Fetching daily data for: 2006-12-14
# 🔄 Fetching daily data for: 2006-12-15
# 🔄 Fetching daily data for: 2006-12-16
# 🔄 Fetching daily data for: 2006-12-17
# 🔄 Fetching daily data for: 2006-12-18
# 🔄 Fetching daily data for: 2006-12-19
# 🔄 Fetching daily data for: 2006-12-20
# 🔄 Fetching daily data for: 2006-12-21
# 🔄 Fetching daily data for: 2006-12-22
# 🔄 Fetching daily data for: 2006-12-23
# 🔄 Fetching daily data for: 2006-12-24
# 🔄 Fetching daily data for: 2017-07-05
# 🔄 Fetching daily data for: 2017-07-06
# 🔄 Fetching daily data for: 2017-07-07
# 🔄 Fetching daily data for: 2017-07-08
# 🔄 Fetching daily data for: 2017-07-09
# 🔄 Fetching daily data for: 2017-07-10
# 🔄 Fetching daily data for: 2017-07-11
# 🔄 Fetching daily data for: 2017-07-12
# 🔄 Fetching daily data for: 2017-07-13
# 🔄 Fetching daily data for: 2017-07-14
# 🔄 Fetching daily data for: 2017-07-15
# 🔄 Fetching daily data for: 2017-07-16
# 🔄 Fetching daily data for: 2017-07-17
# 🔄 Fetching daily data for: 2017-07-18
# 🔄 Fetching daily data for: 2017-07-19
# 🔄 Fetching daily data for: 2017-07-20
# 🔄 Fetching daily data for: 2017-07-21
# 🔄 Fetching daily data for: 2017-07-22
# 🔄 Fetching daily data for: 2017-07-23
# 🔄 Fetching daily data for: 2017-07-24
# 🔄 Fetching daily data for: 2017-07-25
# 🔄 Fetching daily data for: 2017-07-26
# 🔄 Fetching daily data for: 2017-07-27
# 🔄 Fetching daily data for: 2017-07-28
# 🔄 Fetching daily data for: 2017-07-29
# 🔄 Fetching daily data for: 2017-07-30
# 🔄 Fetching daily data for: 2017-07-31
# 🔄 Fetching daily data for: 2017-08-01
# 🔄 Fetching daily data for: 2017-08-02
# 🔄 Fetching daily data for: 2017-08-03
# 🔄 Fetching daily data for: 2017-08-04
# 🔄 Fetching daily data for: 2017-08-05
# 🔄 Fetching daily data for: 2017-08-06
# 🔄 Fetching daily data for: 2017-08-07
# 🔄 Fetching daily data for: 2017-08-08
# 🔄 Fetching daily data for: 2017-08-09
# 🔄 Fetching daily data for: 2017-08-10
# 🔄 Fetching daily data for: 2017-08-11
# 🔄 Fetching daily data for: 2017-08-12
# 🔄 Fetching daily data for: 2017-08-13
# 🔄 Fetching daily data for: 2017-08-14
# 🔄 Fetching daily data for: 2017-08-15
# 🔄 Fetching daily data for: 2017-08-16
# 🔄 Fetching daily data for: 2017-08-17
# 🔄 Fetching daily data for: 2017-08-18
# 🔄 Fetching daily data for: 2017-08-19
# 🔄 Fetching daily data for: 2017-08-20
# 🔄 Fetching daily data for: 2017-08-21
# 🔄 Fetching daily data for: 2017-08-22
# 🔄 Fetching daily data for: 2017-08-23
# 🔄 Fetching daily data for: 2017-08-24
# 🔄 Fetching daily data for: 2017-08-25
# 🔄 Fetching daily data for: 2017-08-26
# 🔄 Fetching daily data for: 2017-08-27
# 🔄 Fetching daily data for: 2017-08-28
# 🔄 Fetching daily data for: 2017-08-29
# 🔄 Fetching daily data for: 2017-08-30
# 🔄 Fetching daily data for: 2017-08-31
# 🔄 Fetching daily data for: 2017-09-01
# 🔄 Fetching daily data for: 2017-09-02
# 🔄 Fetching daily data for: 2017-09-03
# 🔄 Fetching daily data for: 2017-09-04
# 🔄 Fetching daily data for: 2017-09-05
# 🔄 Fetching daily data for: 2017-09-06
# 🔄 Fetching daily data for: 2017-09-07
# 🔄 Fetching daily data for: 2017-09-08
# 🔄 Fetching daily data for: 2017-11-13
# 🔄 Fetching daily data for: 2017-11-14
# 🔄 Fetching daily data for: 2017-11-15
# 🔄 Fetching daily data for: 2017-11-16
# 🔄 Fetching daily data for: 2017-11-17
# 🔄 Fetching daily data for: 2017-11-18
# 🔄 Fetching daily data for: 2017-11-19
# 🔄 Fetching daily data for: 2017-11-20
# 🔄 Fetching daily data for: 2017-11-21
# 🔄 Fetching daily data for: 2017-11-22
# 🔄 Fetching daily data for: 2017-11-23
# 🔄 Fetching daily data for: 2017-11-24
# 🔄 Fetching daily data for: 2017-11-25
# 🔄 Fetching daily data for: 2017-11-26
# 🔄 Fetching daily data for: 2017-11-27
# 🔄 Fetching daily data for: 2017-11-28
# 🔄 Fetching daily data for: 2017-11-29
# 🔄 Fetching daily data for: 2017-11-30
# 🔄 Fetching daily data for: 2017-12-01
# 🔄 Fetching daily data for: 2017-12-02
# 🔄 Fetching daily data for: 2017-12-03
# 🔄 Fetching daily data for: 2017-12-04
# 🔄 Fetching daily data for: 2017-12-05
# 🔄 Fetching daily data for: 2017-12-06
# 🔄 Fetching daily data for: 2017-12-07
# 🔄 Fetching daily data for: 2017-12-08
# 🔄 Fetching daily data for: 2017-12-09
# 🔄 Fetching daily data for: 2017-12-10
# 🔄 Fetching daily data for: 2017-12-11
# 🔄 Fetching daily data for: 2017-12-12
# 🔄 Fetching daily data for: 2017-12-13
# 🔄 Fetching daily data for: 2017-12-14
# 🔄 Fetching daily data for: 2017-12-15
# 🔄 Fetching daily data for: 2017-12-16
# 🔄 Fetching daily data for: 2017-12-17
# 🔄 Fetching daily data for: 2017-12-18
# 🔄 Fetching daily data for: 2017-12-19
# 🔄 Fetching daily data for: 2017-12-20
# 🔄 Fetching daily data for: 2017-12-21
# 🔄 Fetching daily data for: 2017-12-22
# 🔄 Fetching daily data for: 2017-12-23
# 🔄 Fetching daily data for: 2017-12-24
# 🔄 Fetching daily data for: 2017-12-25
# 🔄 Fetching daily data for: 2017-12-26
# 🔄 Fetching daily data for: 2017-12-27
# 🔄 Fetching daily data for: 2017-12-28
# 🔄 Fetching daily data for: 2017-12-29
# 🔄 Fetching daily data for: 2017-12-30
# 🔄 Fetching daily data for: 2017-12-31
# 🔄 Fetching daily data for: 2018-01-01
# 🔄 Fetching daily data for: 2018-01-02
# 🔄 Fetching daily data for: 2018-01-03
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 37
#      34         print("❌ No data could be retrieved")
#      36 if __name__ == "__main__":
# ---> 37     main()
#
# Cell In[38], line 18, in main()
#      15 # Test with a single location
#      16 print(f"\n🌍 Fetching DAILY data for {city} City...")
# ---> 18 data = fetcher.get_data(
#      19     lat=30.0444,
#      20     lon=31.2358,
#      21     start_date="2004-01-01",
#      22     end_date="2025-09-15",
#      23     variables=['temp', 'humidity', 'pressure', 'precipitation', 'solar_rad', 'wind_speed']
#      24 )
#      26 if not data.empty:
#      27     print(f"\n✅ SUCCESS! Retrieved {len(data)} real data points")
#
# Cell In[34], line 69, in GLDASFetcher.get_data(self, lat, lon, start_date, end_date, variables, dataset)
#      64 current_date = start_dt
#      66 while current_date <= end_dt:
#      67
#      68     # Get daily aggregated data for this date
# ---> 69     daily_data = self._fetch_daily_aggregated_data(lat, lon, current_date, variables)
#      70     if daily_data is not None:
#      71         all_data.append(daily_data)
#
# Cell In[34], line 95, in GLDASFetcher._fetch_daily_aggregated_data(self, lat, lon, date, variables)
#      92     print(f"🔄 Fetching daily data for: {date.strftime('%Y-%m-%d')}")
#      94     # Use NASA POWER API for daily meteorological data
# ---> 95     real_data = self._get_nasa_power_daily_data(lat, lon, date, variables)
#      97     return real_data
#      99 except Exception as e:
#
# Cell In[34], line 139, in GLDASFetcher._get_nasa_power_daily_data(self, lat, lon, date, variables)
#     128 params = {
#     129     'parameters': ','.join(power_params),
#     130     'community': 'RE',
#    (...)    135     'format': 'JSON'
#     136 }
#     138 # Make request to NASA POWER
# --> 139 response = requests.get(base_url, params=params, timeout=30)
#     141 if response.status_code == 200:
#     142     data = response.json()
#
# File C:\Program Files\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File C:\Program Files\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File C:\Program Files\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File C:\Program Files\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File C:\Program Files\Python313\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File C:\Program Files\Python313\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File C:\Program Files\Python313\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File C:\Program Files\Python313\Lib\site-packages\urllib3\connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\Python313\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Program Files\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\Program Files\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("nasa_daily_weather_data.csv")

# %%
df
# Out:
#          date  latitude  longitude  temp_max  temp_min  humidity_specific  \
# 0  2025-09-12   30.0444    31.2358     37.88     20.63               9.68
# 1  2025-09-13   30.0444    31.2358     37.79     21.53               9.02
# 2  2025-09-14   30.0444    31.2358     38.65     21.70              10.24
# 3  2025-09-15   30.0444    31.2358     36.43     21.73              11.38
#
#    pressure  precipitation_total  solar_radiation  wind_speed
# 0     99.38                  0.0           6.6281        2.63
# 1     99.50                  0.0           6.6442        1.92
# 2     99.53                  0.0           6.4788        3.06
# 3     99.54                  0.0           6.4042        2.91
